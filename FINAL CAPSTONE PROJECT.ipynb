# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:/Users/ADMIN/Downloads/archive (14)/car_price_prediction.csv")
df.head(1)
# Out:
#          ID  Price  Levy Manufacturer   Model  Prod. year Category  \
# 0  45654403  13328  1399        LEXUS  RX 450        2010     Jeep
#
#   Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0              Yes    Hybrid           3.5  186005 km          6
#
#   Gear box type Drive wheels   Doors       Wheel   Color  Airbags
# 0     Automatic          4x4  04-May  Left wheel  Silver       12

# %%
df=df.drop(['ID','Levy','Model','Category','Leather interior','Engine volume','Drive wheels','Doors','Wheel','Color','Airbags'],axis=1)

# %%
df
# Out:
#        Price   Manufacturer  Prod. year Fuel type    Mileage  Cylinders  \
# 0      13328          LEXUS        2010    Hybrid  186005 km          6
# 1      16621      CHEVROLET        2011    Petrol  192000 km          6
# 2       8467          HONDA        2006    Petrol  200000 km          4
# 3       3607           FORD        2011    Hybrid  168966 km          4
# 4      11726          HONDA        2014    Petrol   91901 km          4
# ...      ...            ...         ...       ...        ...        ...
# 19232   8467  MERCEDES-BENZ        1999       CNG  300000 km          4
# 19233  15681        HYUNDAI        2011    Petrol  161600 km          4
# 19234  26108        HYUNDAI        2010    Diesel  116365 km          4
# 19235   5331      CHEVROLET        2007    Diesel   51258 km          4
# 19236    470        HYUNDAI        2012    Hybrid  186923 km          4
#
#       Gear box type
# 0         Automatic
# 1         Tiptronic
# 2          Variator
# ...

# %%
df.duplicated().value_counts()
# Out:
# False    15613
# True      3624
# dtype: int64

# %%
df=df.drop_duplicates()
df
# Out:
#        Price   Manufacturer  Prod. year Fuel type    Mileage  Cylinders  \
# 0      13328          LEXUS        2010    Hybrid  186005 km          6
# 1      16621      CHEVROLET        2011    Petrol  192000 km          6
# 2       8467          HONDA        2006    Petrol  200000 km          4
# 3       3607           FORD        2011    Hybrid  168966 km          4
# 4      11726          HONDA        2014    Petrol   91901 km          4
# ...      ...            ...         ...       ...        ...        ...
# 19230    470         TOYOTA        2011    Hybrid  307325 km          4
# 19232   8467  MERCEDES-BENZ        1999       CNG  300000 km          4
# 19233  15681        HYUNDAI        2011    Petrol  161600 km          4
# 19234  26108        HYUNDAI        2010    Diesel  116365 km          4
# 19236    470        HYUNDAI        2012    Hybrid  186923 km          4
#
#       Gear box type
# 0         Automatic
# 1         Tiptronic
# 2          Variator
# ...

# %%
df['Mileage']=df['Mileage'].str.strip('km').astype('int64')

# %%
df
# Out:
#        Price   Manufacturer  Prod. year Fuel type  Mileage  Cylinders  \
# 0      13328          LEXUS        2010    Hybrid   186005          6
# 1      16621      CHEVROLET        2011    Petrol   192000          6
# 2       8467          HONDA        2006    Petrol   200000          4
# 3       3607           FORD        2011    Hybrid   168966          4
# 4      11726          HONDA        2014    Petrol    91901          4
# ...      ...            ...         ...       ...      ...        ...
# 19230    470         TOYOTA        2011    Hybrid   307325          4
# 19232   8467  MERCEDES-BENZ        1999       CNG   300000          4
# 19233  15681        HYUNDAI        2011    Petrol   161600          4
# 19234  26108        HYUNDAI        2010    Diesel   116365          4
# 19236    470        HYUNDAI        2012    Hybrid   186923          4
#
#       Gear box type
# 0         Automatic
# 1         Tiptronic
# 2          Variator
# 3         Automatic
# ...

# %%
sns.boxplot(df['Price'])
# Out:
# <Axes: >

# %%
sorted(df['Price'],reverse = True)
# Out:
# [26307500,
#  872946,
#  627220,
#  308906,
#  297930,
#  297930,
#  288521,
#  260296,
#  254024,
#  250574,
#  228935,
#  219527,
#  216391,
#  194438,
#  193184,
#  175622,
#  172486,
#  172486,
#  172486,
#  172486,
#  167781,
#  163077,
#  156805,
#  156805,
#  153669,
#  150533,
#  150533,
#  147397,
#  147397,
#  144261,
#  141124,
#  141124,
#  141124,
#  141124,
#  141124,
#  141124,
#  137885,
#  136420,
#  136000,
#  133284,
#  132971,
#  131716,
#  131716,
#  131716,
#  131308,
#  130148,
#  129521,
#  127000,
#  126322,
#  125500,
#  125444,
#  124989,
#  123330,
#  122308,
#  121681,
#  121524,
#  120740,
#  119172,
#  119172,
#  119172,
#  119009,
#  118676,
#  118519,
#  117604,
#  117604,
#  117290,
#  116036,
#  116036,
#  114468,
#  114468,
#  114468,
#  114154,
#  113025,
#  112900,
#  111332,
#  111332,
#  111332,
#  111002,
#  109764,
#  109764,
#  109764,
#  108371,
#  107841,
#  106957,
#  106668,
#  106627,
#  106627,
#  106627,
#  106627,
#  106627,
# ...

# %%
df[~(df['Price']>=308906) & (df['Price']<=26307500)]
# Out:
#        Price   Manufacturer  Prod. year Fuel type  Mileage  Cylinders  \
# 0      13328          LEXUS        2010    Hybrid   186005          6
# 1      16621      CHEVROLET        2011    Petrol   192000          6
# 2       8467          HONDA        2006    Petrol   200000          4
# 3       3607           FORD        2011    Hybrid   168966          4
# 4      11726          HONDA        2014    Petrol    91901          4
# ...      ...            ...         ...       ...      ...        ...
# 19230    470         TOYOTA        2011    Hybrid   307325          4
# 19232   8467  MERCEDES-BENZ        1999       CNG   300000          4
# 19233  15681        HYUNDAI        2011    Petrol   161600          4
# 19234  26108        HYUNDAI        2010    Diesel   116365          4
# 19236    470        HYUNDAI        2012    Hybrid   186923          4
#
#       Gear box type
# 0         Automatic
# 1         Tiptronic
# 2          Variator
# 3         Automatic
# ...

# %%
df['Fuel type'].unique()
# Out:
# array(['Hybrid', 'Petrol', 'Diesel', 'CNG', 'Plug-in Hybrid', 'LPG',
#        'Hydrogen'], dtype=object)

# %%
df['Fuel type']=df['Fuel type'].map({'Hybrid':0,'Petrol':1,'Diesel':2, 'CNG':3, 'Plug-in Hybrid':4, 'LPG':5,
       'Hydrogen':6})

# %%
df['Fuel type'].unique()
# Out:
# array([0, 1, 2, 3, 4, 5, 6], dtype=int64)

# %%
df['Gear box type'].unique()
# Out:
# array(['Automatic', 'Tiptronic', 'Variator', 'Manual'], dtype=object)

# %%
df['Gear box type']=df['Gear box type'].map({'Automatic':0, 'Tiptronic':1, 'Variator':2, 'Manual':3})

# %%
df['Gear box type'].unique()
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
df.head(1)
# Out:
#    Price Manufacturer  Prod. year  Fuel type  Mileage  Cylinders  \
# 0  13328        LEXUS        2010          0   186005          6
#
#    Gear box type
# 0              0

# %%
X = df.drop(['Manufacturer','Price'],axis = 1)
y = df['Price']

print(X)
print(y)
# Out:
#        Prod. year  Fuel type  Mileage  Cylinders  Gear box type
# 0            2010          0   186005          6              0
# 1            2011          1   192000          6              1
# 2            2006          1   200000          4              2
# 3            2011          0   168966          4              0
# 4            2014          1    91901          4              0
# ...           ...        ...      ...        ...            ...
# 19230        2011          0   307325          4              0
# 19232        1999          3   300000          4              3
# 19233        2011          1   161600          4              1
# 19234        2010          2   116365          4              0
# 19236        2012          0   186923          4              0
#
# [15613 rows x 5 columns]
# 0        13328
# 1        16621
# 2         8467
# 3         3607
# 4        11726
#          ...
# 19230      470
# 19232     8467
# 19233    15681
# 19234    26108
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=  train_test_split(X,y,test_size=0.20,random_state=42)

# %%
df
# Out:
#        Price   Manufacturer  Prod. year  Fuel type  Mileage  Cylinders  \
# 0      13328          LEXUS        2010          0   186005          6
# 1      16621      CHEVROLET        2011          1   192000          6
# 2       8467          HONDA        2006          1   200000          4
# 3       3607           FORD        2011          0   168966          4
# 4      11726          HONDA        2014          1    91901          4
# ...      ...            ...         ...        ...      ...        ...
# 19230    470         TOYOTA        2011          0   307325          4
# 19232   8467  MERCEDES-BENZ        1999          3   300000          4
# 19233  15681        HYUNDAI        2011          1   161600          4
# 19234  26108        HYUNDAI        2010          2   116365          4
# 19236    470        HYUNDAI        2012          0   186923          4
#
#        Gear box type
# 0                  0
# 1                  1
# 2                  2
# 3                  0
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor

# %%
lr  = LinearRegression()
lr.fit(X_train,y_train)

rf = RandomForestRegressor()
rf.fit(X_train,y_train)

xgb = GradientBoostingRegressor()
xgb.fit(X_train,y_train)

xg = XGBRegressor()
xg.fit(X_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
y_pred1 = lr.predict(X_test)
y_pred2 = rf.predict(X_test)
y_pred3 = xgb.predict(X_test)
y_pred4 = xg.predict(X_test)

# %%
from sklearn import metrics
score1 = metrics.r2_score(y_test,y_pred1)
score2 = metrics.r2_score(y_test,y_pred2)
score3 = metrics.r2_score(y_test,y_pred3)
score4 = metrics.r2_score(y_test,y_pred4)

# %%
print(score1,score2,score3,score4)
# Out:
# -0.0008556231930358926 -0.0007927149980870851 -0.00025365837366586597 -0.00043038405838768945

# %%
final_data = pd.DataFrame({'Models':['LR','RF','XGB','XG'],'R2_SCORE':[score1,score2,score3,score4]})

# %%
final_data
# Out:
#   Models  R2_SCORE
# 0     LR -0.000856
# 1     RF -0.000793
# 2    XGB -0.000254
# 3     XG -0.000430

# %%
df.corr()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_9968\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                   Price  Prod. year  Fuel type   Mileage  Cylinders  \
# Price          1.000000    0.014652   0.008282 -0.002021   0.010645
# Prod. year     0.014652    1.000000  -0.099348 -0.064348  -0.125865
# Fuel type      0.008282   -0.099348   1.000000  0.016741   0.024904
# Mileage       -0.002021   -0.064348   0.016741  1.000000   0.000642
# Cylinders      0.010645   -0.125865   0.024904  0.000642   1.000000
# Gear box type  0.012282   -0.500180   0.031382  0.041642   0.000965
#
#                Gear box type
# Price               0.012282
# Prod. year         -0.500180
# Fuel type           0.031382
# Mileage             0.041642
# Cylinders           0.000965
# ...

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_9968\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
xg = XGBRegressor()
xg_final = xg.fit(X,y)

# %%
import joblib

# %%
joblib.dump(xg_final,'Car_price_predictor')
# Out:
# ['Car_price_predictor']

# %%
model = joblib.load('Car_price_predictor')

# %%
df.head(1)
# Out:
#    Price Manufacturer  Prod. year  Fuel type  Mileage  Cylinders  \
# 0  13328        LEXUS        2010          0   186005          6
#
#    Gear box type
# 0              0

# %%
import pandas as pd
data_new = pd.DataFrame({
    'Prod. year': 2005,
    'Fuel type': 1,
    'Mileage' : 15000,
    'Cylinders': 2,
    'Gear box type': 2
}, index=[0])

# %%
model.predict(data_new)
# Out:
# array([13591.899], dtype=float32)
